# %% [markdown]
# <a href="https://colab.research.google.com/github/sejpalrayjada89/MyFirstPortfolio/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x_cgpa = [2,3,4,5]
y_salary = [20000,30000,40000,50000]

# %%
plt.plot(x_cgpa,y_salary,"o--g")
plt.xlabel("CGPA")
plt.ylabel("Salary")
plt.title("Salary and CGPA Distribution")
plt.show()
